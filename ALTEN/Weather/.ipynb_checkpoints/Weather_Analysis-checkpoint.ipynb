# %%
import pandas as pd

# %%
data = pd.read_table("Data/debilt.txt",skiprows=50,sep=',', na_values='     ')

# %%
data.head()
# Out:
#    # STN  YYYYMMDD  DDVEC  FHVEC     FG    FHX   FHXH    FHN   FHNH    FXX  \
# 0    260  19010101    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1    260  19010102    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    260  19010103    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3    260  19010104    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4    260  19010105    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#    ...   VVNH    VVX   VVXH     NG     UG     UX    UXH     UN    UNH   EV24
# 0  ...    NaN    NaN    NaN    NaN   66.0    NaN    NaN    NaN    NaN    NaN
# 1  ...    NaN    NaN    NaN    NaN   86.0    NaN    NaN    NaN    NaN    NaN
# 2  ...    NaN    NaN    NaN    NaN   89.0    NaN    NaN    NaN    NaN    NaN
# 3  ...    NaN    NaN    NaN    NaN   79.0    NaN    NaN    NaN    NaN    NaN
# 4  ...    NaN    NaN    NaN    NaN   65.0    NaN    NaN    NaN    NaN    NaN
#
# [5 rows x 41 columns]

# %%
data.describe()
# Out:
#          # STN      YYYYMMDD         DDVEC         FHVEC            FG  \
# count  45292.0  4.529200e+04  44167.000000  44167.000000  44167.000000
# mean     260.0  1.962569e+07    190.048951     36.126090     41.382820
# std        0.0  3.579578e+05     93.973225     19.948677     19.100916
# min      260.0  1.901010e+07      0.000000      0.000000      0.000000
# 25%      260.0  1.932010e+07    121.000000     21.000000     26.000000
# 50%      260.0  1.963010e+07    207.000000     33.000000     36.000000
# 75%      260.0  1.994010e+07    256.000000     46.000000     51.000000
# max      260.0  2.025010e+07    360.000000    149.000000    165.000000
#
#                 FHX          FHXH           FHN          FHNH           FXX  \
# count  44167.000000  44167.000000  44167.000000  44167.000000  26664.000000
# mean      62.367831     11.953087     21.531075     10.127335    106.390977
# std       25.675003      6.060763     15.446131      8.578781     41.553616
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data.insert(loc=1,column='Year',value = data.YYYYMMDD.astype(str).str[:4].astype(int))
data.insert(loc=2,column='Month',value = data.YYYYMMDD.astype(str).str[4:6].astype(int))
data.insert(loc=3,column='Day',value = data.YYYYMMDD.astype(str).str[6:8].astype(int))

# %%
year = [1993]
month = [8]#range(1,12)

mask1 = data.Year.isin(year)
mask2 = data.Month.isin(month)
total_mask = mask1&mask2

plt.figure(figsize=(12,6))
plt.suptitle(('Weather analysis in De Bilt in {} of {}').format(month,year))
plt.subplot(1, 2, 1)
plt.scatter(np.arange(total_mask.sum()),data["   TX"].loc[total_mask]/10,c='red')
plt.scatter(np.arange(total_mask.sum()),data["   TN"].loc[total_mask]/10,c='blue')
plt.title('Temperature')
plt.xticks(ticks = np.arange(total_mask.sum()),labels=data.YYYYMMDD[total_mask],rotation=90)
plt.ylabel('Temperature [C]')
plt.legend(['Max','Min'])

plt.subplot(1, 2, 2)
plt.scatter(np.arange(total_mask.sum()),data["   SQ"][total_mask]/10,c='orange')
plt.title('Amount of sun')
plt.xticks(ticks = np.arange(total_mask.sum()),labels=data.YYYYMMDD[total_mask],rotation=90)
plt.ylabel('Sun duration [h]')
plt.show()
