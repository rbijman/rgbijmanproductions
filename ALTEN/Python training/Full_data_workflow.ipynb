# %%
import pandas as pd

# %%
pd.read_excel('Course_Materials/Course_Materials_Part2/Video_Lecture_NBs/sales.xls')
# Out:
#   Unnamed: 0      City Country  Sales  Bonus
# 0       Mike  New York     USA     25   2.50
# 1        Jim    Boston     USA     43   4.30
# 2     Steven    London      UK     76   7.60
# 3        Joe    Madrid   Spain     12   1.80
# 4        Tom     Paris  France     89  13.35

# %%
url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 url
#
# NameError: name 'url' is not defined

# %%
url = 'https://en.wikipedia.org/wiki/1976_Summer_Olympics_medal_table'

# %%
pd.read_html(url)[3]
# Out:
#                    Rank                  NOC  Gold  Silver  Bronze  Total
# 0                     1         Soviet Union    49      41      35    125
# 1                     2         East Germany    40      25      25     90
# 2                     3        United States    34      35      25     94
# 3                     4         West Germany    10      12      17     39
# 4                     5                Japan     9       6      10     25
# 5                     6               Poland     7       6      13     26
# 6                     7             Bulgaria     6       9       7     22
# 7                     8                 Cuba     6       4       3     13
# 8                     9              Romania     4       9      14     27
# 9                    10              Hungary     4       5      13     22
# 10                   11              Finland     4       2       0      6
# 11                   12               Sweden     4       1       0      5
# ...
