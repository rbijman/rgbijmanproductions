# %%
import pandas as pd

# %%
titanic = pd.read_csv(r"Course_Materials/Course_Materials_Part1/Video_Lecture_NBs/titanic.csv")

# %%
print(titanic)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.info
# Out:
# <bound method DataFrame.info of      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]>

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.describe(include = "O")
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
round(titanic)
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked deck
# 0           0       3    male  22.0      1      0   7.0        S  NaN
# 1           1       1  female  38.0      1      0  71.0        C    C
# 2           1       3  female  26.0      0      0   8.0        S  NaN
# 3           1       1  female  35.0      1      0  53.0        S    C
# 4           0       3    male  35.0      0      0   8.0        S  NaN
# ..        ...     ...     ...   ...    ...    ...   ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0        S  NaN
# 887         1       1  female  19.0      0      0  30.0        S    B
# 888         0       3  female   NaN      1      2  23.0        S  NaN
# 889         1       1    male  26.0      0      0  30.0        C    C
# 890         0       3    male  32.0      0      0   8.0        Q  NaN
#
# [891 rows x 9 columns]

# %%
min(titanic)
# Out:
# 'age'

# %% [markdown]
# ## Dataframe attributes

# %% [markdown]
# an attribute is a feature or characteristic of an object that is already stored in the object

# %%
titanic.shape
# Out:
# (891, 9)

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %% [markdown]
# ## Dataframe methods

# %% [markdown]
# A metod is a function specifically designed for that datatype/class. It is a callable

# %%
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
# 5         0       3    male   NaN      0      0   8.4583        Q  NaN
# 6         0       1    male  54.0      0      0  51.8625        S    E
# 7         0       3    male   2.0      3      1  21.0750        S  NaN
# 8         1       3  female  27.0      0      2  11.1333        S  NaN
# 9         1       2  female  14.0      1      0  30.0708        C  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.min(numeric_only=True)
# Out:
# survived    0.00
# pclass      1.00
# age         0.42
# sibsp       0.00
# parch       0.00
# fare        0.00
# dtype: float64

# %% [markdown]
# ## method chaining

# %%
titanic.mean(numeric_only=True).sort_values().head(2)
# Out:
# parch       0.381594
# survived    0.383838
# dtype: float64

# %%
titanic.sort_values(by="age")
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 803         1       3    male  0.42      0      1   8.5167        C  NaN
# 755         1       2    male  0.67      1      1  14.5000        S  NaN
# 644         1       3  female  0.75      2      1  19.2583        C  NaN
# 469         1       3  female  0.75      2      1  19.2583        C  NaN
# 78          1       2    male  0.83      0      2  29.0000        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %% [markdown]
# ## Selection columns

# %%
type(titanic["age"])
# Out:
# pandas.core.series.Series

# %%
type(titanic.age)
# Out:
# pandas.core.series.Series

# %%
titanic[["age","sex"]]
# Out:
#       age     sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %% [markdown]
# ## Position based indexing

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.iloc[1]
# Out:
# survived          1
# pclass            1
# sex          female
# age            38.0
# sibsp             1
# parch             0
# fare        71.2833
# embarked          C
# deck              C
# Name: 1, dtype: object

# %%
summer = pd.read_csv("Course_Materials/Course_Materials_Part1/Video_Lecture_NBs/summer.csv",index_col='Athlete')

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31165 entries, HAJOS, Alfred to LIDBERG, Jimmy
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Country     31161 non-null  object
#  5   Gender      31165 non-null  object
#  6   Event       31165 non-null  object
#  7   Medal       31165 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %%
summer.iloc[-1]
# Out:
# Year                         2012
# City                       London
# Sport                   Wrestling
# Discipline    Wrestling Freestyle
# Country                       SWE
# Gender                        Men
# Event                    Wg 96 KG
# Medal                      Bronze
# Name: LIDBERG, Jimmy, dtype: object

# %%
summer.iloc[1:3]
# Out:
#                    Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto   1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                         Event   Medal
# Athlete
# HERSCHMANN, Otto               100M Freestyle  Silver
# DRIVAS, Dimitrios  100M Freestyle For Sailors  Bronze

# %%
summer.iloc[-5:]
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender     Event   Medal
# Athlete
# JANIKOWSKI, Damian            POL    Men  Wg 84 KG  Bronze
# REZAEI, Ghasem Gholamreza     IRI    Men  Wg 96 KG    Gold
# TOTROV, Rustam                RUS    Men  Wg 96 KG  Silver
# ALEKSANYAN, Artur             ARM    Men  Wg 96 KG  Bronze
# LIDBERG, Jimmy                SWE    Men  Wg 96 KG  Bronze

# %%
summer.iloc[[2, 45, 5457]]
# Out:
#                    Year       City       Sport   Discipline Country Gender  \
# Athlete
# DRIVAS, Dimitrios  1896     Athens    Aquatics     Swimming     GRE    Men
# PERSAKIS, Ioannis  1896     Athens   Athletics    Athletics     GRE    Men
# MOREMAN, Marjorie  1928  Amsterdam  Gymnastics  Artistic G.     GBR  Women
#
#                                         Event   Medal
# Athlete
# DRIVAS, Dimitrios  100M Freestyle For Sailors  Bronze
# PERSAKIS, Ioannis                 Triple Jump  Bronze
# MOREMAN, Marjorie            Team Competition  Bronze

# %%
summer.head(10)
# Out:
#                        Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto       1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios      1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          1896  Athens  Aquatics   Swimming     AUT    Men
#
#                                             Event   Medal
# Athlete
# HAJOS, Alfred                      100M Freestyle    Gold
# ...

# %%
summer.iloc[34:39,[0, 2, 5, 7]]
# Out:
#                       Year      Sport Gender   Medal
# Athlete
# GARRETT, Robert       1896  Athletics    Men  Silver
# KELLNER, Gyula        1896  Athletics    Men  Bronze
# LOUIS, Spyridon       1896  Athletics    Men    Gold
# VASILAKOS, Kharilaos  1896  Athletics    Men  Silver
# DAMASKOS, Evangelos   1896  Athletics    Men  Bronze

# %% [markdown]
# ## Label based indexing

# %%
summer.iloc[2]
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: DRIVAS, Dimitrios, dtype: object

# %%
summer.loc[["PHELPS, Michael","LEWIS, Carl"],["Medal","Event"]]
# Out:
#                   Medal                   Event
# Athlete
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael  Bronze          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# PHELPS, Michael  Bronze  4X100M Freestyle Relay
# PHELPS, Michael    Gold     4X100M Medley Relay
# PHELPS, Michael    Gold  4X200M Freestyle Relay
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael    Gold          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# PHELPS, Michael    Gold  4X100M Freestyle Relay
# PHELPS, Michael    Gold     4X100M Medley Relay
# PHELPS, Michael    Gold  4X200M Freestyle Relay
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael  Silver          200M Butterfly
# ...

# %%
summer.loc[:,["Medal","Event"]]
# Out:
#                             Medal                       Event
# Athlete
# HAJOS, Alfred                Gold              100M Freestyle
# HERSCHMANN, Otto           Silver              100M Freestyle
# DRIVAS, Dimitrios          Bronze  100M Freestyle For Sailors
# MALOKINIS, Ioannis           Gold  100M Freestyle For Sailors
# CHASAPIS, Spiridon         Silver  100M Freestyle For Sailors
# ...                           ...                         ...
# JANIKOWSKI, Damian         Bronze                    Wg 84 KG
# REZAEI, Ghasem Gholamreza    Gold                    Wg 96 KG
# TOTROV, Rustam             Silver                    Wg 96 KG
# ALEKSANYAN, Artur          Bronze                    Wg 96 KG
# LIDBERG, Jimmy             Bronze                    Wg 96 KG
#
# [31165 rows x 2 columns]

# %%
summer.head(10)
# Out:
#                        Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto       1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios      1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          1896  Athens  Aquatics   Swimming     AUT    Men
#
#                                             Event   Medal
# Athlete
# HAJOS, Alfred                      100M Freestyle    Gold
# ...

# %%
summer.loc[:"CHASAPIS, Spiridon"]
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
summer.loc["BOS, Theo"]
# Out:
# Year                     2004
# City                   Athens
# Sport                 Cycling
# Discipline      Cycling Track
# Country                   NED
# Gender                    Men
# Event         Sprint Indivual
# Medal                  Silver
# Name: BOS, Theo, dtype: object

# %%
print(summer.loc["UNDA, Maider","Event"])
# Out:
# Wf 72 KG

# %% [markdown]
# ## Reindexing

# %%
summer.loc[[0,5,30000],["Athlete","Medal"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 summer.loc[[0,5,30000],["Athlete","Medal"]]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1375, in _LocIndexer._getitem_tuple(self, tup)
#    1373 # ugly hack for GH #836
#    1374 if self._multi_take_opportunity(tup):
# -> 1375     return self._multi_take(tup)
#    1377 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
summer = pd.read_csv("Course_Materials/Course_Materials_Part1/Video_Lecture_NBs/summer.csv")

# %%
summer.reindex(index=[0, 5, 30000, 40000],columns=["Athlete","Medal","Age"])
# Out:
#                      Athlete   Medal  Age
# 0              HAJOS, Alfred    Gold  NaN
# 5      CHOROPHAS, Efstathios  Bronze  NaN
# 30000       PAUTARAN, Maryna  Bronze  NaN
# 40000                    NaN     NaN  NaN

# %%
summer.loc[:,["Medal"]]
# Out:
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 1 columns]

# %%
rows = list(range(5)) + [354,765]

# %%
rows
# Out:
# [0, 1, 2, 3, 4, 354, 765]

# %%
summer.iloc[rows]
# Out:
#      Year      City       Sport Discipline             Athlete Country Gender  \
# 0    1896    Athens    Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1    1896    Athens    Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2    1896    Athens    Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3    1896    Athens    Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4    1896    Athens    Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
# 354  1900     Paris  Equestrian    Jumping       DE BELLEGARDE     FRA    Men
# 765  1904  St Louis   Athletics  Athletics       CORAY, Albert     ZZX    Men
#
#                           Event   Medal
# 0                100M Freestyle    Gold
# 1                100M Freestyle  Silver
# 2    100M Freestyle For Sailors  Bronze
# 3    100M Freestyle For Sailors    Gold
# 4    100M Freestyle For Sailors  Silver
# 354        Long Jump Individual  Bronze
# 765                 4Miles Team  Silver

# %%
col = summer.columns[:3].to_list() + ["Gender","Event"]

# %%
col
# Out:
# ['Year', 'City', 'Sport', 'Gender', 'Event']

# %%
summer.loc[:,col]
# Out:
#        Year    City      Sport Gender                       Event
# 0      1896  Athens   Aquatics    Men              100M Freestyle
# 1      1896  Athens   Aquatics    Men              100M Freestyle
# 2      1896  Athens   Aquatics    Men  100M Freestyle For Sailors
# 3      1896  Athens   Aquatics    Men  100M Freestyle For Sailors
# 4      1896  Athens   Aquatics    Men  100M Freestyle For Sailors
# ...     ...     ...        ...    ...                         ...
# 31160  2012  London  Wrestling    Men                    Wg 84 KG
# 31161  2012  London  Wrestling    Men                    Wg 96 KG
# 31162  2012  London  Wrestling    Men                    Wg 96 KG
# 31163  2012  London  Wrestling    Men                    Wg 96 KG
# 31164  2012  London  Wrestling    Men                    Wg 96 KG
#
# [31165 rows x 5 columns]

# %%
a = summer.iloc[[200,300]].loc[:,"Sport"]
a
# Out:
# 200     Aquatics
# 300    Athletics
# Name: Sport, dtype: object

# %%
summer.loc[[200,300],summer.columns[[5,7]]]
# Out:
#     Country        Event
# 200     GBR   Water Polo
# 300     USA  Triple Jump

# %% [markdown]
# summer.loc[summer.index[100:300],summer.columns[2:4]]

# %%
summer.index
# Out:
# RangeIndex(start=0, stop=31165, step=1)
